# %% [markdown]
# #Random Temporal Networks v1.0#

# %%
import sys
sys.path.append("/home/luffy/Bureau/Random/Library/")
import RandTempNet as rn
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Snapshot sequence permutations##
# We here present randomization techniques based on the snapshot sequence representation. All functions take a snapshot_sequence() object as input, and return a snapshot_sequence() object.
# ###Permutation of active snapshots $\text{P}[p(G^t),\text{sgn}(\mathbf{E})]$: `P__pGt_sgnE(seq_data)`###
# This function randomly permutates the active snapshots of a `snapshot_sequence()` object `seq_data`.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
new_seq = rn.P__pGt_sgnE(seq_data)

# %%
TL0 = rn.activity_timeline(seq_data)
TL1 = rn.activity_timeline(new_seq)

tmin = 1000
tmax = 2000

fig = plt.figure(figsize=(8,2))
x = range(len(TL0))[tmin:tmax]
plt.plot(x,TL0[tmin:tmax],'k-')
plt.plot(x,TL1[tmin:tmax],'r-')
plt.show()

# %% [markdown]
# ###Permutation of snapshots $\text{P}[p(G^t)]$: `P__pGt(seq_data)`###
# This function randomly permutates all the snapshots of a `snapshot_sequence()` object `seq_data`.

# %%
new_seq = rn.P__pGt(seq_data)

# %%
TL2 = rn.activity_timeline(new_seq)

tmin = 1000
tmax = 2000

fig = plt.figure(figsize=(8,2))
x = range(len(TL0))[tmin:tmax]
plt.plot(x,TL0[tmin:tmax],'k-')
plt.plot(x,TL2[tmin:tmax],'r-')
plt.show()

# %% [markdown]
# ###Permutation of node identites in snapshots between active nodes $\text{P}[{\rm iso}(G^t),\Phi]$: `P__isoGt_Phi(seq_data)`###
# This function randomly permutates the identities of active nodes within each snapshot of a `snapshot_sequence()` object `seq_data`.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
new_seq = rn.P__isoGt_Phi(seq_data)

# %%
list_lk_0 = seq_data.data[1503].display()
list_lk_1 = new_seq.data[1503].display()

fig = plt.figure(figsize=(8,4))
ax_0 = fig.add_axes([0,0,0.5,1])
ax_1 = fig.add_axes([0.5,0,0.5,1])
import networkx as nx
G = nx.Graph()
G.add_edges_from(list_lk_0)
nx.draw_networkx(G,ax=ax_0)
G = nx.Graph()
G.add_edges_from(list_lk_1)
nx.draw_networkx(G,ax=ax_1)
ax_0.set_xticks([])
ax_0.set_yticks([])
ax_1.set_xticks([])
ax_1.set_yticks([])
# Out:
# []

# %% [markdown]
# ###Permutation of node identities in snapshots between all nodes $\text{P}[{\rm iso}(G^t)]$: `P__isoGt(seq_data)`###
# This function randomly permutates the identity of nodes within each snapshot of a `snapshot_sequence()` object `seq_data`.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
new_seq = rn.P__isoGt(seq_data)

# %%
list_lk_0 = seq_data.data[1503].display()
list_lk_1 = new_seq.data[1503].display()

fig = plt.figure(figsize=(8,4))
ax_0 = fig.add_axes([0,0,0.5,1])
ax_1 = fig.add_axes([0.5,0,0.5,1])
import networkx as nx
G = nx.Graph()
G.add_edges_from(list_lk_0)
nx.draw_networkx(G,ax=ax_0)
G = nx.Graph()
G.add_edges_from(list_lk_1)
nx.draw_networkx(G,ax=ax_1)
ax_0.set_xticks([])
ax_0.set_yticks([])
ax_1.set_xticks([])
ax_1.set_yticks([])
# Out:
# []

# %% [markdown]
# ###Permutation of events in snapshots with preserved degrees $\text{P}[\mathbf{k}]$: `P__k(seq_data,link_threshold=20,n_iter=5)`###
# This function randomly permutates links within each snapshot while preserving the instantaneous degrees of the nodes, for a `snapshot_sequence()` object `seq_data`. We use to algorithms to do so. If the number of links in the snapshot if larger than `link_threshold` then we use a configuration model. If it is lower, we use the Sneppen-Maslov algorith, which we iterate $n_\text{iter}\times n_L$ times.
#
# This choice is due to the fact that exploring the set of possible networks via the configuration model can be extremely inefficient for small networks.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
seq_data.data = {t:seq_data.data[t] for t in seq_data.data if t < 1510}
new_seq = rn.P__k(seq_data)

# %%
list_lk_0 = seq_data.data[1503].display()
list_lk_1 = new_seq.data[1503].display()

fig = plt.figure(figsize=(8,4))
ax_0 = fig.add_axes([0,0,0.5,1])
ax_1 = fig.add_axes([0.5,0,0.5,1])
import networkx as nx
G = nx.Graph()
G.add_edges_from(list_lk_0)
nx.draw_networkx(G,ax=ax_0)
G = nx.Graph()
G.add_edges_from(list_lk_1)
nx.draw_networkx(G,ax=ax_1)
ax_0.set_xticks([])
ax_0.set_yticks([])
ax_1.set_xticks([])
ax_1.set_yticks([])
# Out:
# []

# %% [markdown]
# ###Permutation of events between active nodes in each snapshot $\text{P}[\Phi]$: `P__Phi(seq_data)`###
# This function randomly permutates links between active nodes within each snapshot of a `snapshot_sequence()` object `seq_data`.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
new_seq = rn.P__Phi(seq_data)

# %%
list_lk_0 = seq_data.data[1503].display()
list_lk_1 = new_seq.data[1503].display()

fig = plt.figure(figsize=(8,4))
ax_0 = fig.add_axes([0,0,0.5,1])
ax_1 = fig.add_axes([0.5,0,0.5,1])
import networkx as nx
G = nx.Graph()
G.add_edges_from(list_lk_0)
nx.draw_networkx(G,ax=ax_0)
G = nx.Graph()
G.add_edges_from(list_lk_1)
nx.draw_networkx(G,ax=ax_1)
ax_0.set_xticks([])
ax_0.set_yticks([])
ax_1.set_xticks([])
ax_1.set_yticks([])
# Out:
# []

# %% [markdown]
# ###Permutation of events in snapshots $\text{P}[\mathbf{E}]$: `P__E(seq_data)`###
# This function randomly permutates links within each snapshot of a `snapshot_sequence()` object `seq_data`.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
new_seq = rn.P__E(seq_data)

# %%
list_lk_0 = seq_data.data[1503].display()
list_lk_1 = new_seq.data[1503].display()

fig = plt.figure(figsize=(8,4))
ax_0 = fig.add_axes([0,0,0.5,1])
ax_1 = fig.add_axes([0.5,0,0.5,1])
import networkx as nx
G = nx.Graph()
G.add_edges_from(list_lk_0)
nx.draw_networkx(G,ax=ax_0)
G = nx.Graph()
G.add_edges_from(list_lk_1)
nx.draw_networkx(G,ax=ax_1)
ax_0.set_xticks([])
ax_0.set_yticks([])
ax_1.set_xticks([])
ax_1.set_yticks([])
# Out:
# []

# %% [markdown]
# ###Global permutation of events $\text{P}[\mu_E]$: `P__muE(seq_data)`###
# This function randomly permutates events of a `snapshot_sequence()` object `seq_data`.

# %%
seq_data = rn.read_snapshot_sequence("Bureau/Random/Library/timeset_InVS13.dat")
new_seq = rn.P__muE(seq_data)

# %%
TL0 = rn.activity_timeline(seq_data)
TL1 = rn.activity_timeline(new_seq)

tmin = 1000
tmax = 2000

fig = plt.figure(figsize=(8,2))
x = range(len(TL0))[tmin:tmax]
plt.plot(x,TL0[tmin:tmax],'k-')
plt.plot(x,TL1[tmin:tmax],'r-')
plt.show()
